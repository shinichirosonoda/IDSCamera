# %%
from get_fov import Get_Angle_data
import cv2
import matplotlib.pyplot as plt

# %%
# file
file_name = "2230.png"
file = "./data/" + file_name

img0 = cv2.cvtColor(cv2.imread(file, 1), cv2.COLOR_BGR2GRAY)
img1 = cv2.imread(file, 1)[:,:,::-1]

# select filename
plt.gray()
plt.title("gray image")
plt.imshow(img0)
plt.show()

img0[0:500,0:2456]=0

# select filename
plt.gray()
plt.title("gray image")
plt.imshow(img0)
plt.show()

# %%
img, _, _ , _= Get_Angle_data(img0)

# %%
plt.imshow(img)
plt.show()
